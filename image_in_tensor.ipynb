# %%
import torch
import matplotlib.pyplot as plt
from torchvision import transforms
from PIL import Image

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    print ('cuda')
else:
    device = torch.device('cpu')

device
# Out:
# device(type='cpu')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/MyDrive/image.jpeg'

# %%
image_path = path
image=Image.open(image_path)

# %%
#Display the image
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
image_transform =transforms.ToTensor()
image_tensor = image_transform(image)

# %%
plt.imshow(image_tensor.permute(1,2,0))
plt.title('Transformed Image')
plt.axis('off')
plt.show()

# %%
print(image_tensor.shape)
print(image_tensor)
# Out:
# torch.Size([3, 168, 300])
# tensor([[[0.4235, 0.3647, 0.3451,  ..., 0.3098, 0.3137, 0.3137],
#          [0.3569, 0.3098, 0.2941,  ..., 0.3059, 0.3137, 0.3059],
#          [0.3490, 0.3176, 0.2980,  ..., 0.3373, 0.3020, 0.3137],
#          ...,
#          [0.5882, 0.5843, 0.5804,  ..., 0.5373, 0.5412, 0.5412],
#          [0.5765, 0.5765, 0.5725,  ..., 0.6000, 0.6000, 0.6000],
#          [0.5765, 0.5765, 0.5843,  ..., 0.7216, 0.7255, 0.7255]],
#
#         [[0.4667, 0.4078, 0.3882,  ..., 0.3608, 0.3647, 0.3647],
#          [0.4000, 0.3529, 0.3373,  ..., 0.3569, 0.3647, 0.3569],
#          [0.4039, 0.3725, 0.3529,  ..., 0.3882, 0.3529, 0.3647],
#          ...,
#          [0.5843, 0.5804, 0.5765,  ..., 0.5451, 0.5490, 0.5490],
#          [0.5725, 0.5725, 0.5686,  ..., 0.6000, 0.6000, 0.6000],
#          [0.5725, 0.5725, 0.5804,  ..., 0.7216, 0.7255, 0.7255]],
#
#         [[0.3412, 0.2824, 0.2706,  ..., 0.3333, 0.3373, 0.3373],
# ...

# %%
image_tensor[0,0,0]
# for red channel first pixel value
# Out:
# tensor(0.4235)

# %%
image_tensor[1,0,0]
# for blue channel first pixel value
# Out:
# tensor(0.4667)

# %%
image_tensor[2,0,0]
# for green channel first pixel value
# Out:
# tensor(0.3412)

# %%
path='/content/drive/MyDrive/grey.png'
image_path=path
image=Image.open(image_path)
image_tensor=image_transform(image)

# %%
plt.imshow(image,cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
plt.imshow(image_tensor.permute(1,2,0),cmap='gray')
plt.title('Transformed Image')
plt.axis('off')
plt.show()

# %%
print("tensor")
print(image_tensor.shape)
print(image_tensor)
# Out:
# tensor
# torch.Size([3, 800, 800])
# tensor([[[0.1216, 0.1294, 0.1490,  ..., 0.0353, 0.0353, 0.0353],
#          [0.1216, 0.1294, 0.1490,  ..., 0.0353, 0.0353, 0.0353],
#          [0.1216, 0.1294, 0.1490,  ..., 0.0314, 0.0314, 0.0314],
#          ...,
#          [0.2196, 0.1569, 0.0824,  ..., 0.0471, 0.0471, 0.0471],
#          [0.2235, 0.2314, 0.2118,  ..., 0.0471, 0.0471, 0.0471],
#          [0.2157, 0.2941, 0.2392,  ..., 0.0471, 0.0471, 0.0471]],
#
#         [[0.1294, 0.1373, 0.1569,  ..., 0.0392, 0.0392, 0.0392],
#          [0.1294, 0.1373, 0.1569,  ..., 0.0392, 0.0392, 0.0392],
#          [0.1294, 0.1373, 0.1569,  ..., 0.0353, 0.0353, 0.0353],
#          ...,
#          [0.2196, 0.1569, 0.0824,  ..., 0.0353, 0.0353, 0.0353],
#          [0.2235, 0.2314, 0.2118,  ..., 0.0353, 0.0353, 0.0353],
#          [0.2157, 0.2941, 0.2392,  ..., 0.0353, 0.0353, 0.0353]],
#
#         [[0.1373, 0.1451, 0.1647,  ..., 0.0667, 0.0667, 0.0667],
# ...
