# %% [markdown]
# # **BASIC BINARY CLASSIFICATION MODEL WITH SIMPLE NEURAL NETWORK**

# %% [markdown]
# IT IS FULLY CONNECTED NEURAL NETWORK I AM NOT USING CNN HERE

# %% [markdown]
# # Create , train and save a simple neural netwrok

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader , Dataset
from torchvision.datasets import ImageFolder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import numpy as np

# %%
torch.manual_seed(10)

# %% [markdown]
# lets try a basic binary classification model for two typs of

# %%
# Defining a simple neural network architecture
class modelNN(nn.Module):
  def __init__(self, input_size, hidden_size, output_size):
    super(modelNN, self).__init__()
    self.fc1 = nn.Linear(3 * 256 * 256 , 128)
    self.relu = nn.ReLU()
    self.fc2 = nn.Linear(128, 64)
    self.relu = nn.ReLU()
    self.fc3 = nn.Linear(64, 32)
    self.relu = nn.ReLU()
    self.fc4 = nn.Linear(32, 2)
    self.softmax = nn.Softmax(dim=1)

  def forward(self, x):
    x = x.view(-1,3*256*256)
    x = self.fc1(x)
    x = self.relu(x)
    x = self.fc2(x)
    x = self.relu(x)
    x = self.fc3(x)
    x = self.relu(x)
    x = self.fc4(x)
    x = self.softmax(x)
    return x

# %%
# setting up data transfornm
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))])

# %%
#define clas for dataset
class CustomDataset(Dataset):
  def __init__(self, root, transform=None):
    self.dataset = ImageFolder(root, transform=transform)

  def __len__(self):
    return len(self.dataset)

  def __getitem__(self, idx):
    #image, label = self.dataset[idx]
    return self.dataset[idx]

# %%
#DATA LOADERS
train_dataset= CustomDataset(root='/content/drive/MyDrive/Car_Classification/train', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=64, num_workers=8, shuffle=True)

test_dataset = CustomDataset(root='/content/drive/MyDrive/Car_Classification/test', transform=transform)
test_loader = DataLoader(test_dataset, batch_size=64, num_workers=8, shuffle=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
model = modelNN(input_size=3*256*256, hidden_size=128, output_size=2)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5)  # Reduce LR if validation loss plateaus

# %%
for name, param in model.named_parameters():
    if 'weight' in name:
        print(f"Layer: {name}, Weight Shape: {param.shape}, Weight Values:\n {param.data}\n")
        # Access the weight values: param.data
    elif 'bias' in name:
        print(f"Layer: {name}, Bias Shape: {param.shape}, Bias Values:\n {param.data}\n")
        # Access the bias values: param.data
# Out:
# Layer: fc1.weight, Weight Shape: torch.Size([128, 196608]), Weight Values:
#  tensor([[-1.8906e-04, -7.7326e-05, -8.4574e-04,  ..., -2.0701e-03,
#          -4.2385e-04, -2.7034e-04],
#         [ 2.0040e-03,  2.5180e-04, -1.5096e-03,  ...,  4.1500e-04,
#           9.6482e-04, -1.5813e-03],
#         [-1.4448e-03, -2.6457e-04, -1.4462e-04,  ...,  1.7498e-04,
#          -1.3295e-03,  1.7719e-03],
#         ...,
#         [ 3.4997e-04, -3.0144e-04, -5.1299e-04,  ...,  1.8477e-04,
#          -1.2476e-03,  4.4823e-04],
#         [ 2.0800e-03,  1.5789e-03, -2.2551e-03,  ..., -2.2477e-03,
#          -2.1587e-03, -1.7000e-03],
#         [-2.7455e-04,  2.0644e-03,  3.9773e-04,  ..., -5.7787e-04,
#           1.4072e-03,  1.8312e-03]])
#
# Layer: fc1.bias, Bias Shape: torch.Size([128]), Bias Values:
#  tensor([ 6.6251e-04, -1.9871e-03, -6.7548e-05, -4.9345e-04, -9.9455e-04,
#          1.0047e-03,  6.3896e-04, -1.8644e-03, -1.8027e-04,  1.3844e-03,
#          1.1769e-03,  2.1064e-03, -1.1034e-04, -2.5999e-04,  1.5285e-03,
#          1.8528e-03, -4.3986e-04,  1.2889e-03,  1.7431e-04, -2.2508e-03,
#         -2.6218e-04, -1.7865e-03, -1.7303e-03,  1.2820e-03,  9.9531e-04,
#         -1.6406e-03, -1.7284e-06,  1.0032e-03, -2.1354e-03, -7.1972e-04,
#          1.9432e-03,  1.4269e-03, -7.2322e-04,  6.1651e-04,  1.9090e-03,
#         -1.4240e-03, -2.3488e-04,  8.4555e-04, -8.4645e-04,  8.3067e-05,
#         -9.5521e-04,  1.8090e-04, -9.4041e-04, -4.0417e-04, -2.1718e-03,
#         -1.3176e-03,  1.0003e-03,  6.3130e-05, -1.4208e-03, -2.1451e-03,
#          1.7581e-03, -2.0978e-03,  7.3415e-04, -1.6486e-03, -4.5241e-04,
#         -1.7649e-03,  9.0735e-04, -2.9604e-05, -9.7811e-05, -1.0910e-03,
#          2.2247e-03,  1.7234e-03,  7.1357e-04,  6.2049e-05,  9.8888e-04,
#          8.6447e-04, -1.4923e-03, -9.5361e-07,  1.5692e-03,  5.9962e-04,
#         -7.5429e-04, -2.0573e-03,  4.5602e-04,  7.8583e-04,  1.2668e-03,
#          2.0469e-04, -8.2032e-04, -1.7264e-03,  1.8391e-03,  1.5738e-03,
#          1.7316e-04, -6.7344e-05,  1.0143e-03, -1.5890e-03,  1.5402e-03,
#          1.7879e-03,  1.1827e-03, -1.3611e-04, -1.8064e-03, -7.2216e-04,
#         -1.9315e-03,  6.0124e-05,  7.5209e-04,  1.1204e-03, -8.4499e-04,
#          1.3754e-03, -1.8824e-04, -1.4098e-03,  4.0677e-04, -3.3782e-04,
#         -5.0167e-04,  1.2920e-03, -1.1075e-03,  2.0825e-03, -7.4356e-04,
#          1.0758e-03, -1.3520e-03, -1.2977e-03,  2.1641e-03,  1.0113e-03,
#         -3.4340e-04,  4.4243e-04, -9.5219e-04, -1.5122e-03,  1.8231e-03,
#         -1.4528e-03, -2.0492e-03,  1.9180e-03,  6.0590e-04, -6.3853e-04,
#         -1.4403e-04,  1.1088e-03, -7.1274e-05,  5.3464e-04,  5.5427e-04,
#         -3.7996e-04,  2.5082e-04, -1.0240e-03])
#
# Layer: fc2.weight, Weight Shape: torch.Size([64, 128]), Weight Values:
#  tensor([[-0.0229,  0.0725,  0.0390,  ...,  0.0446, -0.0227, -0.0734],
#         [ 0.0619, -0.0417, -0.0098,  ..., -0.0722, -0.0098, -0.0027],
#         [ 0.0213, -0.0497,  0.0847,  ...,  0.0305,  0.0758, -0.0563],
#         ...,
#         [ 0.0428, -0.0123, -0.0323,  ..., -0.0348, -0.0851,  0.0118],
#         [-0.0026,  0.0714, -0.0439,  ...,  0.0474, -0.0174, -0.0289],
#         [ 0.0437, -0.0128, -0.0179,  ...,  0.0559, -0.0676,  0.0735]])
#
# Layer: fc2.bias, Bias Shape: torch.Size([64]), Bias Values:
#  tensor([ 0.0365,  0.0684,  0.0443,  0.0474, -0.0223,  0.0318,  0.0434, -0.0786,
#         -0.0707,  0.0018, -0.0860,  0.0437, -0.0635, -0.0293, -0.0468, -0.0423,
#         -0.0470,  0.0660, -0.0352, -0.0314, -0.0664, -0.0229, -0.0847,  0.0866,
#          0.0176, -0.0855,  0.0443,  0.0734, -0.0063, -0.0659,  0.0363,  0.0072,
#          0.0372,  0.0030,  0.0697,  0.0141, -0.0793,  0.0058,  0.0863,  0.0306,
#          0.0256,  0.0664, -0.0543, -0.0319,  0.0563, -0.0242,  0.0634, -0.0150,
#          0.0172,  0.0404,  0.0145, -0.0506,  0.0668,  0.0346, -0.0253,  0.0015,
#         -0.0448,  0.0150,  0.0212,  0.0577, -0.0770,  0.0864, -0.0287,  0.0154])
#
# Layer: fc3.weight, Weight Shape: torch.Size([32, 64]), Weight Values:
#  tensor([[-0.0931, -0.0469,  0.0095,  ..., -0.0076,  0.1027,  0.1218],
#         [-0.1015,  0.0267, -0.0099,  ..., -0.0745, -0.0635, -0.0731],
#         [-0.0219, -0.0990,  0.0415,  ...,  0.0578,  0.0761, -0.0032],
#         ...,
#         [ 0.0016,  0.1192, -0.1191,  ..., -0.1121, -0.1028,  0.0834],
#         [ 0.0219,  0.0379, -0.0256,  ..., -0.0453,  0.0631,  0.0184],
#         [ 0.0578, -0.1103, -0.0101,  ...,  0.1139,  0.0504,  0.0172]])
#
# Layer: fc3.bias, Bias Shape: torch.Size([32]), Bias Values:
#  tensor([ 0.1045,  0.0943,  0.1044,  0.0375, -0.0004,  0.1076,  0.0150, -0.0710,
#          0.0990, -0.1027,  0.0148, -0.0145,  0.0215,  0.0165, -0.0211, -0.0906,
#          0.0947,  0.0236, -0.0321, -0.0493,  0.0110,  0.0360, -0.0510,  0.0333,
#          0.0288,  0.0931,  0.0241, -0.1021,  0.1231,  0.1075, -0.0049,  0.0733])
#
# Layer: fc4.weight, Weight Shape: torch.Size([2, 32]), Weight Values:
#  tensor([[-0.0602, -0.0097, -0.0519, -0.0479, -0.1507,  0.1087, -0.0253, -0.1287,
#           0.1427, -0.0312, -0.1742, -0.0475,  0.0140, -0.1142,  0.0778, -0.0112,
#           0.0095,  0.1580,  0.0941, -0.0558, -0.0592, -0.0392, -0.1089, -0.1273,
#          -0.0317,  0.1738, -0.1698, -0.0102, -0.0654, -0.1359,  0.1472, -0.0486],
#         [ 0.1556, -0.0124,  0.0411,  0.0904, -0.1734, -0.1193, -0.0299,  0.1279,
#          -0.0795,  0.0572, -0.0158,  0.0430, -0.0161, -0.1673, -0.1199,  0.1452,
#          -0.1516, -0.1091, -0.0988,  0.0686, -0.1244,  0.1108,  0.0971, -0.1212,
#          -0.1556, -0.0155,  0.0861, -0.1151, -0.0706, -0.1036,  0.0259,  0.1219]])
#
# Layer: fc4.bias, Bias Shape: torch.Size([2]), Bias Values:
#  tensor([-0.0617,  0.0668])

# %%
# !nvidia-smi
# Out:
# Wed Dec 18 22:48:44 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# TRAINING LOOP

# %%
num_epochs= 50
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
train_loss=[]
valid_loss=[]
#train_accuracy=[]



for epoch in range(num_epochs):
  #model training
  model.train()
  running_loss = 0.0
  print(f'Epoch [{epoch+1}/{num_epochs}]')
  for images, labels in train_loader:
    images = images.to(device)
    labels = labels.to(device)

    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()
    running_loss += loss.item()


  average_train_loss= running_loss / len(train_loader)
  print(average_train_loss,'average_loss')
  train_loss.append(average_train_loss)  # will append the loss in outer loop means it is appending at each epochs

  #validation
  model.eval()
  Evalid_loss = 0.0
  with torch.no_grad():
    for images, labels in test_loader:
      images = images.to(device)
      labels = labels.to(device)

      outputs = model(images)
      loss = criterion(outputs, labels)
      Evalid_loss += loss.item()

    average_valid_loss = Evalid_loss / len(test_loader)
    valid_loss.append(average_valid_loss)

    scheduler.step(average_valid_loss)

  print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {average_train_loss:.4f}, Valid Loss: {average_valid_loss:.4f}')
# Out:
# Epoch [1/50]
# 0.7394609619986336 average_loss
# Epoch [1/50], Train Loss: 0.7395, Valid Loss: 0.7039
# Epoch [2/50]
# 0.7402781248092651 average_loss
# Epoch [2/50], Train Loss: 0.7403, Valid Loss: 0.7039
# Epoch [3/50]
# 0.738570047999328 average_loss
# Epoch [3/50], Train Loss: 0.7386, Valid Loss: 0.7039
# Epoch [4/50]
# 0.7394277779561169 average_loss
# Epoch [4/50], Train Loss: 0.7394, Valid Loss: 0.7039
# Epoch [5/50]
# 0.7412621637560287 average_loss
# Epoch [5/50], Train Loss: 0.7413, Valid Loss: 0.7039
# Epoch [6/50]
# 0.7405742631768281 average_loss
# Epoch [6/50], Train Loss: 0.7406, Valid Loss: 0.7039
# Epoch [7/50]
# 0.7412621502606374 average_loss
# Epoch [7/50], Train Loss: 0.7413, Valid Loss: 0.7039
# Epoch [8/50]
# 0.7401156605414625 average_loss
# Epoch [8/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [9/50]
# 0.7398863670960912 average_loss
# Epoch [9/50], Train Loss: 0.7399, Valid Loss: 0.7039
# Epoch [10/50]
# 0.7410328613137299 average_loss
# Epoch [10/50], Train Loss: 0.7410, Valid Loss: 0.7039
# Epoch [11/50]
# 0.7401156729122378 average_loss
# Epoch [11/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [12/50]
# 0.7403449596099134 average_loss
# Epoch [12/50], Train Loss: 0.7403, Valid Loss: 0.7039
# Epoch [13/50]
# 0.741720754020619 average_loss
# Epoch [13/50], Train Loss: 0.7417, Valid Loss: 0.7039
# Epoch [14/50]
# 0.7414914470798565 average_loss
# Epoch [14/50], Train Loss: 0.7415, Valid Loss: 0.7039
# Epoch [15/50]
# 0.7403449629837612 average_loss
# Epoch [15/50], Train Loss: 0.7403, Valid Loss: 0.7039
# Epoch [16/50]
# 0.7419500485906061 average_loss
# Epoch [16/50], Train Loss: 0.7420, Valid Loss: 0.7039
# Epoch [17/50]
# 0.7391984856353616 average_loss
# Epoch [17/50], Train Loss: 0.7392, Valid Loss: 0.7039
# Epoch [18/50]
# 0.7403449573606815 average_loss
# Epoch [18/50], Train Loss: 0.7403, Valid Loss: 0.7039
# Epoch [19/50]
# 0.7405742631768281 average_loss
# Epoch [19/50], Train Loss: 0.7406, Valid Loss: 0.7039
# Epoch [20/50]
# 0.741262157008333 average_loss
# Epoch [20/50], Train Loss: 0.7413, Valid Loss: 0.7039
# Epoch [21/50]
# 0.7408035667437427 average_loss
# Epoch [21/50], Train Loss: 0.7408, Valid Loss: 0.7039
# Epoch [22/50]
# 0.7401156672891581 average_loss
# Epoch [22/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [23/50]
# 0.7398863727191709 average_loss
# Epoch [23/50], Train Loss: 0.7399, Valid Loss: 0.7039
# Epoch [24/50]
# 0.740344967482225 average_loss
# Epoch [24/50], Train Loss: 0.7403, Valid Loss: 0.7039
# Epoch [25/50]
# 0.7394277779561169 average_loss
# Epoch [25/50], Train Loss: 0.7394, Valid Loss: 0.7039
# Epoch [26/50]
# 0.7396570669030244 average_loss
# Epoch [26/50], Train Loss: 0.7397, Valid Loss: 0.7039
# Epoch [27/50]
# 0.7405742609275962 average_loss
# Epoch [27/50], Train Loss: 0.7406, Valid Loss: 0.7039
# Epoch [28/50]
# 0.740803561120663 average_loss
# Epoch [28/50], Train Loss: 0.7408, Valid Loss: 0.7039
# Epoch [29/50]
# 0.7401156661645422 average_loss
# Epoch [29/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [30/50]
# 0.7389691865669107 average_loss
# Epoch [30/50], Train Loss: 0.7390, Valid Loss: 0.7039
# Epoch [31/50]
# 0.7396570815230316 average_loss
# Epoch [31/50], Train Loss: 0.7397, Valid Loss: 0.7039
# Epoch [32/50]
# 0.7401156616660783 average_loss
# Epoch [32/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [33/50]
# 0.7403449551114496 average_loss
# Epoch [33/50], Train Loss: 0.7403, Valid Loss: 0.7039
# Epoch [34/50]
# 0.7394277712084213 average_loss
# Epoch [34/50], Train Loss: 0.7394, Valid Loss: 0.7039
# Epoch [35/50]
# 0.7398863670960912 average_loss
# Epoch [35/50], Train Loss: 0.7399, Valid Loss: 0.7039
# Epoch [36/50]
# 0.740344966357609 average_loss
# Epoch [36/50], Train Loss: 0.7403, Valid Loss: 0.7039
# Epoch [37/50]
# 0.7401156661645422 average_loss
# Epoch [37/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [38/50]
# 0.7401156751614697 average_loss
# Epoch [38/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [39/50]
# 0.7403449742299206 average_loss
# Epoch [39/50], Train Loss: 0.7403, Valid Loss: 0.7039
# Epoch [40/50]
# 0.7405742620522121 average_loss
# Epoch [40/50], Train Loss: 0.7406, Valid Loss: 0.7039
# Epoch [41/50]
# 0.7394277790807328 average_loss
# Epoch [41/50], Train Loss: 0.7394, Valid Loss: 0.7039
# Epoch [42/50]
# 0.7410328568152662 average_loss
# Epoch [42/50], Train Loss: 0.7410, Valid Loss: 0.7039
# Epoch [43/50]
# 0.7401156695383899 average_loss
# Epoch [43/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [44/50]
# 0.7403449629837612 average_loss
# Epoch [44/50], Train Loss: 0.7403, Valid Loss: 0.7039
# Epoch [45/50]
# 0.7401156785353175 average_loss
# Epoch [45/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [46/50]
# 0.7405742564291324 average_loss
# Epoch [46/50], Train Loss: 0.7406, Valid Loss: 0.7039
# Epoch [47/50]
# 0.739886370469939 average_loss
# Epoch [47/50], Train Loss: 0.7399, Valid Loss: 0.7039
# Epoch [48/50]
# 0.7401156684137741 average_loss
# Epoch [48/50], Train Loss: 0.7401, Valid Loss: 0.7039
# Epoch [49/50]
# 0.7389691786945991 average_loss
# Epoch [49/50], Train Loss: 0.7390, Valid Loss: 0.7039
# Epoch [50/50]
# 0.7401156706630059 average_loss
# Epoch [50/50], Train Loss: 0.7401, Valid Loss: 0.7039

# %%
#nvidia-smi

# %% [markdown]
# MODEL EVALUATION

# %%
#evaluation of model
def evaluate_model(model, dataloader):
  model.eval()
  all_preds = []
  all_labels = []

  with torch.no_grad():
    for images, labels in dataloader:
      images = images.to(device)
      labels = labels.to(device)
      outputs = model(images)
      _, preds = torch.max(outputs, 1)
      all_preds.extend(preds.cpu().numpy())
      all_labels.extend(labels.cpu().numpy())

  accuracy = accuracy_score(all_labels, all_preds)
  precision = precision_score(all_labels, all_preds, average='weighted')
  recall = recall_score(all_labels, all_preds, average='weighted')
  f1 = f1_score(all_labels, all_preds, average='weighted')

  print(f'Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}')
  return accuracy, precision, recall, f1


evaluate_model(model, test_loader)
# Out:
# Accuracy: 0.5000, Precision: 0.2500, Recall: 0.5000, F1 Score: 0.3333
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (0.5, 0.25, 0.5, 0.33333333333333326)

# %%
#visualising
plt.plot(train_loss, label='Training Loss')
plt.plot(valid_loss, label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''accuracy, precision, recall, f1 = evaluate_model(model, test_loader)
plt.plot(accuracy, label='Training Accuracy')
#plt.plot(valid_accruacy, label='Validation Accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()'''
# Out:
# "accuracy, precision, recall, f1 = evaluate_model(model, test_loader)\nplt.plot(accuracy, label='Training Accuracy')\n#plt.plot(valid_accruacy, label='Validation Accuracy')\n\nplt.xlabel('Epochs')\nplt.ylabel('Accuracy')\nplt.legend()\nplt.show()"

# %%
#save the model
torch.save(model.state_dict(), 'binary_classification_model.pth')

# %%
#load the model
model = modelNN(input_size=3*256*256, hidden_size=128, output_size=2)
model.load_state_dict(torch.load('binary_classification_model.pth'))
model.eval()
# Out:
# <ipython-input-19-05f0fc905950>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('binary_classification_model.pth'))
# modelNN(
#   (fc1): Linear(in_features=196608, out_features=128, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=2, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
#lets load a unique unseen image for testing
from PIL import Image
image_path='/content/drive/MyDrive/Car_Classification/image.jpeg'
image = Image.open(image_path)

input_tensor = transform(image).unsqueeze(0)
print(input_tensor.shape)
# Out:
# torch.Size([1, 3, 256, 256])

# %%
#make prediction on the testing image
with torch.no_grad():
  model_output = model(input_tensor)

_, predicted_class = torch.max(model_output, 1)
print(predicted_class)
# Out:
# tensor([1])

# %%
class_labels=['SUV','Sedan']
predicted_class_labels=class_labels[predicted_class.item()]
print("the model predicts that image belongs to ",predicted_class_labels, " class")
# Out:
# the model predicts that image belongs to  Sedan  class

# %%
#import numpy as np
# convert image image to numpy array
image_arr=np.array(image)
plt.imshow(image_arr)
plt.title(predicted_class_labels)
plt.axis('off')
plt.show()

# %%
# !nvidia-smi
# Out:
# Wed Dec 18 23:29:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P0              30W /  70W |    783MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+
